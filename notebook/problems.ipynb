# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment; for example, when you flip a coin, it can be either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution, where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial
import numpy as np

np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %% [markdown]
# #### Normal Distribution

# %%
from scipy.stats import norm

# Probability Density Function - Calculates the probability of x being in a range of values e.g. X being between rangeA and rangeB
def npdf(x, mean=0, std=1):
    output = norm.pdf(x, loc=mean, scale=std)
    return output

# Comulative Distribution Function - Calculates de probability of X being less than or equal to x (given value) - Since this is cummulative, 
# it'e the probability of being equal or less than a given value. e.g p(x) = (X >= 5)
def ncdf(x, mean=0, std=1):
    output = norm.cdf(x, loc=mean, scale=std)
    return output

# Percent Point Function - Calculates the percentile from q (values that are below that number) - 
def nppf(q, mean=0, std=1):
    output = norm.ppf(q, loc=0, scale=1)
    return output

# Random variates - Generates random variables following the mean and std given. 
def nrvs(mean=0, std=1, size=1):
    output = norm.rvs(loc=mean, scale=std, size=1)
    return output

# %%
import numpy as np
from scipy.stats import norm

data = np.arange(-5,5,.1)
mean = 0
std = 1

normal_pdf = npdf(data, mean, std)
normal_cdf = ncdf(data, mean, std)
normal_ppf = nppf(data, mean, std)
normal_rvs = (mean, std, 1)

fig, ax = plt.subplots(3,1, figsize=(8, 9))
fig.suptitle('Normal Distribution - Statistical Functions')
ax[0].plot(data, normal_pdf, label='PDF', color='r')
ax[0].legend()
ax[1].plot(data, normal_cdf, label='CDF', color='b')
ax[1].legend()
ax[2].plot(data, normal_ppf, label='PPF', color='orange')
ax[2].legend()

# %% [markdown]
# #### Uniform Distribution

# %%
from scipy.stats import uniform

# Probability Density Function - Calculates the probability of x being in an specific range
def updf(x, mean=0, std=1):
    output = uniform.pdf(x, loc=mean, scale=std)
    return output

# Comulative Distribution Function - Calculates de probability of X being less than or equal to x (given value)
def ucdf(x, mean=0, std=1):
    output = uniform.cdf(x, loc=mean, scale=std)
    return output

# Percent Point Function - Calculates the percentile from q (values that are below that number)
def uppf(q, mean=0, std=1):
    output = uniform.ppf(q, loc=0, scale=1)
    return output

# Random variates - Generates random variables following the mean and std given. 
def urvs(mean=0, std=1, size=1):
    output = uniform.rvs(loc=mean, scale=std, size=1)
    return output

# %%
from scipy.stats import uniform

data = np.arange(0,100,1)
mean = 47
std = 6

updf = updf(data, mean, std)
ucdf = ucdf(data, mean, std)
uppf = uppf(data, mean, std)

fig, ax = plt.subplots(3, 1, figsize=(8, 9))
fig.suptitle('Uniform Distribution - Statistical Functions')
ax[0].plot(data, updf, label='PDF', c='r')
ax[0].legend()
ax[1].plot(data, ucdf, label='CDF', c='b')
ax[1].legend()
ax[2].plot(data, uppf, label='PPF', c='orange')
ax[2].legend()
